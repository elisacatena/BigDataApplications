# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # Tempi di esecuzione in locale

# %%
job_data_1 = [
    {"input_size": 2.81, "execution_time": 3.46},
    {"input_size": 3.40, "execution_time": 5.10},
    {"input_size": 3.99, "execution_time": 6.52},
    {"input_size": 4.58, "execution_time": 7.59},
]

# Creare un DataFrame
df1 = pd.DataFrame(job_data_1)

# Creare il grafico
fig, ax = plt.subplots(figsize=(10, 5), facecolor='white')
# Impostare lo sfondo interno del grafico come bianco
ax.set_facecolor('white')

# Personalizzare il grafico
ax.plot(df1['input_size'], df1['execution_time'], marker='o', linestyle='-', color='mediumaquamarine', markersize=8, linewidth=2)

# Aggiungere il bordo nero
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(1.5)

# Etichette degli assi
ax.set_xlabel("Dimensione dell'input (GB)", fontsize=12, labelpad=15)
ax.set_ylabel("Tempo di esecuzione (min)", fontsize=12, labelpad=15)

# Titolo del grafico
ax.set_title("Tempo di esecuzione MapReduce (in locale) job3 in funzione della dimensione dell'input", fontsize=16, pad=20)

# Aggiungere una griglia sottile
ax.grid(True, linestyle='--', linewidth=0.5, color='lightgray')

plt.show()

# %%
job_data_2 = [
    {"input_size": 2.81, "execution_time": 4.18},
    {"input_size": 3.40, "execution_time": 5.10},
    {"input_size": 3.99, "execution_time": 5.48},
    {"input_size": 4.58, "execution_time": 6.37},
]

# Creare un DataFrame
df2 = pd.DataFrame(job_data_2)

# Creare il grafico
fig, ax = plt.subplots(figsize=(10, 5), facecolor='white')
# Impostare lo sfondo interno del grafico come bianco
ax.set_facecolor('white')

# Personalizzare il grafico
ax.plot(df2['input_size'], df2['execution_time'], marker='o', linestyle='-', color='lightskyblue', markersize=8, linewidth=2)

# Aggiungere il bordo nero
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(1.5)

# Etichette degli assi
ax.set_xlabel("Dimensione dell'input (GB)", fontsize=12, labelpad=15)
ax.set_ylabel("Tempo di esecuzione (min)", fontsize=12, labelpad=15)

# Titolo del grafico
ax.set_title("Tempo di esecuzione Hive (in locale) job3 in funzione della dimensione dell'input", fontsize=16, pad=20)

# Aggiungere una griglia sottile
ax.grid(True, linestyle='--', linewidth=0.5, color='lightgray')

plt.show()

# %%
job_data_3 = [
    {"input_size": 2.81, "execution_time": 2.39},
    {"input_size": 3.40, "execution_time": 3.20},
    {"input_size": 3.99, "execution_time": 4.01},
    {"input_size": 4.58, "execution_time": 4.34},
]

# Creare un DataFrame
df3 = pd.DataFrame(job_data_3)

# Creare il grafico
fig, ax = plt.subplots(figsize=(10, 5), facecolor='white')
# Impostare lo sfondo interno del grafico come bianco
ax.set_facecolor('white')

# Personalizzare il grafico
ax.plot(df3['input_size'], df3['execution_time'], marker='o', linestyle='-', color='orchid', markersize=8, linewidth=2)

# Aggiungere il bordo nero
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(1.5)

# Etichette degli assi
ax.set_xlabel("Dimensione dell'input (GB)", fontsize=12, labelpad=15)
ax.set_ylabel("Tempo di esecuzione (min)", fontsize=12, labelpad=15)

# Titolo del grafico
ax.set_title("Tempo di esecuzione Spark core (in locale) job3 in funzione della dimensione dell'input",fontsize=16, pad=20)

# Aggiungere una griglia sottile
ax.grid(True, linestyle='--', linewidth=0.5, color='lightgray')

plt.show()

# %%
job_data_4 = [
    {"input_size": 2.81, "execution_time": 1.23},
    {"input_size": 3.40, "execution_time": 1.36},
    {"input_size": 3.99, "execution_time": 1.40},
    {"input_size": 4.58, "execution_time": 1.44},
]

# Creare un DataFrame
df4 = pd.DataFrame(job_data_4)

# Creare il grafico
fig, ax = plt.subplots(figsize=(10, 5), facecolor='white')
# Impostare lo sfondo interno del grafico come bianco
ax.set_facecolor('white')

# Personalizzare il grafico
ax.plot(df4['input_size'], df4['execution_time'], marker='o', linestyle='-', color='slateblue', markersize=8, linewidth=2)

# Aggiungere il bordo nero
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(1.5)

# Etichette degli assi
ax.set_xlabel("Dimensione dell'input (GB)", fontsize=12, labelpad=15)
ax.set_ylabel("Tempo di esecuzione (min)", fontsize=12, labelpad=15)

# Titolo del grafico
ax.set_title("Tempo di esecuzione Spark SQL (in locale) job3 in funzione della dimensione dell'input", fontsize=16, pad=20)

# Aggiungere una griglia sottile
ax.grid(True, linestyle='--', linewidth=0.5, color='lightgray')

plt.show()

# %%
# Creare il grafico
fig, ax = plt.subplots(figsize=(10, 5), facecolor='white')
# Impostare lo sfondo interno del grafico come bianco
ax.set_facecolor('white')

# Personalizzare il grafico
ax.plot(df1['input_size'], df1['execution_time'], marker='o', linestyle='-', color='mediumaquamarine', markersize=8, linewidth=2, label='MapReduce')
ax.plot(df2['input_size'], df2['execution_time'], marker='o', linestyle='-', color='lightskyblue', markersize=8, linewidth=2, label='Hive')
ax.plot(df3['input_size'], df3['execution_time'], marker='o', linestyle='-', color='orchid', markersize=8, linewidth=2, label='Spark core')
ax.plot(df4['input_size'], df4['execution_time'], marker='o', linestyle='-', color='slateblue', markersize=8, linewidth=2, label='Spark SQL')

# Aggiungere il bordo nero
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(1.5)

# Etichette degli assi
ax.set_xlabel("Dimensione dell'input (GB)", fontsize=12, labelpad=15)
ax.set_ylabel("Tempo di esecuzione (min)", fontsize=12, labelpad=15)

# Aggiungere una griglia sottile
ax.grid(True, linestyle='--', linewidth=0.5, color='lightgray')
# Aggiungere la legenda
ax.legend()
# Aggiungere i numeri da 1 a 11 sull'asse y
ax.set_yticks(np.arange(1, 9, 1))
plt.show()

# %% [markdown]
# # Tempi di esecuzione su cluster

# %%
job_data_11 = [
    {"input_size": 2.81, "execution_time": 4.24},
    {"input_size": 3.40, "execution_time": 4.50},
    {"input_size": 3.99, "execution_time": 6.50},
    {"input_size": 4.58, "execution_time": 7.33},
]

# Creare un DataFrame
df11 = pd.DataFrame(job_data_11)

# Creare il grafico
fig, ax = plt.subplots(figsize=(10, 5), facecolor='white')
# Impostare lo sfondo interno del grafico come bianco
ax.set_facecolor('white')

# Personalizzare il grafico
ax.plot(df11['input_size'], df11['execution_time'], marker='o', linestyle='-', color='mediumaquamarine', markersize=8, linewidth=2)

# Aggiungere il bordo nero
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(1.5)

# Etichette degli assi
ax.set_xlabel("Dimensione dell'input (GB)", fontsize=12, labelpad=15)
ax.set_ylabel("Tempo di esecuzione (min)", fontsize=12, labelpad=15)

# Titolo del grafico
ax.set_title("Tempo di esecuzione MapReduce (su cluster) job3 in funzione della dimensione dell'input", fontsize=16, pad=20)

# Aggiungere una griglia sottile
ax.grid(True, linestyle='--', linewidth=0.5, color='lightgray')

plt.show()

# %%
job_data_21 = [
    {"input_size": 2.81, "execution_time": 3.06},
    {"input_size": 3.40, "execution_time": 4.35},
    {"input_size": 3.99, "execution_time": 5.02},
    {"input_size": 4.58, "execution_time": 5.47},
]
   
# Creare un DataFrame
df21 = pd.DataFrame(job_data_21)

# Creare il grafico
fig, ax = plt.subplots(figsize=(10, 5), facecolor='white')
# Impostare lo sfondo interno del grafico come bianco
ax.set_facecolor('white')

# Personalizzare il grafico
ax.plot(df21['input_size'], df21['execution_time'], marker='o', linestyle='-', color='lightskyblue', markersize=8, linewidth=2)

# Aggiungere il bordo nero
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(1.5)

# Etichette degli assi
ax.set_xlabel("Dimensione dell'input (GB)", fontsize=12, labelpad=15)
ax.set_ylabel("Tempo di esecuzione (min)", fontsize=12, labelpad=15)

# Titolo del grafico
ax.set_title("Tempo di esecuzione Hive (su cluster) job3 in funzione della dimensione dell'input", fontsize=16, pad=20)

# Aggiungere una griglia sottile
ax.grid(True, linestyle='--', linewidth=0.5, color='lightgray')

plt.show()

# %%
job_data_31 = [
    {"input_size": 2.81, "execution_time": 4.03},
    {"input_size": 3.40, "execution_time": 5.13},
    {"input_size": 3.99, "execution_time": 6.25},
    {"input_size": 4.58, "execution_time": 6.58},
]

# Creare un DataFrame
df31 = pd.DataFrame(job_data_31)

# Creare il grafico
fig, ax = plt.subplots(figsize=(10, 5), facecolor='white')
# Impostare lo sfondo interno del grafico come bianco
ax.set_facecolor('white')

# Personalizzare il grafico
ax.plot(df31['input_size'], df31['execution_time'], marker='o', linestyle='-', color='orchid', markersize=8, linewidth=2)

# Aggiungere il bordo nero
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(1.5)

# Etichette degli assi
ax.set_xlabel("Dimensione dell'input (GB)", fontsize=12, labelpad=15)
ax.set_ylabel("Tempo di esecuzione (min)", fontsize=12, labelpad=15)

# Titolo del grafico
ax.set_title("Tempo di esecuzione Spark core (su cluster) job3 in funzione della dimensione dell'input", fontsize=16, pad=20)

# Aggiungere una griglia sottile
ax.grid(True, linestyle='--', linewidth=0.5, color='lightgray')

plt.show()

# %%
job_data_41 = [
    {"input_size": 2.81, "execution_time": 0.98},
    {"input_size": 3.40, "execution_time": 1.02},
    {"input_size": 3.99, "execution_time": 1.07},
    {"input_size": 4.58, "execution_time": 1.15},
]

# Creare un DataFrame
df41 = pd.DataFrame(job_data_41)

# Creare il grafico
fig, ax = plt.subplots(figsize=(10, 5), facecolor='white')
# Impostare lo sfondo interno del grafico come bianco
ax.set_facecolor('white')

# Personalizzare il grafico
ax.plot(df41['input_size'], df41['execution_time'], marker='o', linestyle='-', color='slateblue', markersize=8, linewidth=2)

# Aggiungere il bordo nero
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(1.5)

# Etichette degli assi
ax.set_xlabel("Dimensione dell'input (GB)", fontsize=12, labelpad=15)
ax.set_ylabel("Tempo di esecuzione (min)", fontsize=12, labelpad=15)

# Titolo del grafico
ax.set_title("Tempo di esecuzione Spark SQL (su cluster) job3 in funzione della dimensione dell'input", fontsize=16, pad=20)

# Aggiungere una griglia sottile
ax.grid(True, linestyle='--', linewidth=0.5, color='lightgray')

plt.show()

# %%
# Creare il grafico
fig, ax = plt.subplots(figsize=(10, 5), facecolor='white')
# Impostare lo sfondo interno del grafico come bianco
ax.set_facecolor('white')

# Personalizzare il grafico
ax.plot(df11['input_size'], df11['execution_time'], marker='o', linestyle='-', color='mediumaquamarine', markersize=8, linewidth=2, label='MapReduce')
ax.plot(df21['input_size'], df21['execution_time'], marker='o', linestyle='-', color='lightskyblue', markersize=8, linewidth=2, label='Hive')
ax.plot(df31['input_size'], df31['execution_time'], marker='o', linestyle='-', color='orchid', markersize=8, linewidth=2, label='Spark core')
ax.plot(df41['input_size'], df41['execution_time'], marker='o', linestyle='-', color='slateblue', markersize=8, linewidth=2, label='Spark SQL')

# Aggiungere il bordo nero
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(1.5)

# Etichette degli assi
ax.set_xlabel("Dimensione dell'input (GB)", fontsize=12, labelpad=15)
ax.set_ylabel("Tempo di esecuzione (min)", fontsize=12, labelpad=15)

# Aggiungere una griglia sottile
ax.grid(True, linestyle='--', linewidth=0.5, color='lightgray')
# Aggiungere la legenda
ax.legend()

# Aggiungere i numeri da 1 a 11 sull'asse y
ax.set_yticks(np.arange(1, 9, 1))
plt.show()

# %% [markdown]
# ## Confronto tra tempo in locale e su cluster per ogni tecnologia

# %%
# Creare il grafico
fig, ax = plt.subplots(figsize=(10, 5), facecolor='white')
# Impostare lo sfondo interno del grafico come bianco
ax.set_facecolor('white')

# Personalizzare il grafico
ax.plot(df1['input_size'], df1['execution_time'], marker='o', linestyle='-', color='mediumvioletred', markersize=8, linewidth=2, label='MapReduce in locale')
ax.plot(df11['input_size'], df11['execution_time'], marker='o', linestyle='-', color='hotpink', markersize=8, linewidth=2, label='MapReduce su cluster')

# Aggiungere il bordo nero
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(1.5)

# Etichette degli assi
ax.set_xlabel("Dimensione dell'input (GB)", fontsize=12, labelpad=15)
ax.set_ylabel("Tempo di esecuzione (min)", fontsize=12, labelpad=15)

# Aggiungere una griglia sottile
ax.grid(True, linestyle='--', linewidth=0.5, color='lightgray')
# Aggiungere la legenda
ax.legend()

# Aggiungere i numeri da 1 a 11 sull'asse y
ax.set_yticks(np.arange(1, 9, 1))
plt.show()

# %%
# Creare il grafico
fig, ax = plt.subplots(figsize=(10, 5), facecolor='white')
# Impostare lo sfondo interno del grafico come bianco
ax.set_facecolor('white')

# Personalizzare il grafico
ax.plot(df2['input_size'], df2['execution_time'], marker='o', linestyle='-', color='darkslategray', markersize=8, linewidth=2, label='Hive in locale')
ax.plot(df21['input_size'], df21['execution_time'], marker='o', linestyle='-', color='cadetblue', markersize=8, linewidth=2, label='Hive su cluster')

# Aggiungere il bordo nero
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(1.5)

# Etichette degli assi
ax.set_xlabel("Dimensione dell'input (GB)", fontsize=12, labelpad=15)
ax.set_ylabel("Tempo di esecuzione (min)", fontsize=12, labelpad=15)

# Aggiungere una griglia sottile
ax.grid(True, linestyle='--', linewidth=0.5, color='lightgray')
# Aggiungere la legenda
ax.legend()

# Aggiungere i numeri da 1 a 11 sull'asse y
ax.set_yticks(np.arange(1, 8, 1))
plt.show()

# %%
# Creare il grafico
fig, ax = plt.subplots(figsize=(10, 5), facecolor='white')
# Impostare lo sfondo interno del grafico come bianco
ax.set_facecolor('white')

# Personalizzare il grafico
ax.plot(df3['input_size'], df3['execution_time'], marker='o', linestyle='-', color='firebrick', markersize=8, linewidth=2, label='Spark core in locale')
ax.plot(df31['input_size'], df31['execution_time'], marker='o', linestyle='-', color='darksalmon', markersize=8, linewidth=2, label='Spark core su cluster')

# Aggiungere il bordo nero
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(1.5)

# Etichette degli assi
ax.set_xlabel("Dimensione dell'input (GB)", fontsize=12, labelpad=15)
ax.set_ylabel("Tempo di esecuzione (min)", fontsize=12, labelpad=15)

# Aggiungere una griglia sottile
ax.grid(True, linestyle='--', linewidth=0.5, color='lightgray')
# Aggiungere la legenda
ax.legend()

# Aggiungere i numeri da 1 a 11 sull'asse y
ax.set_yticks(np.arange(1, 8, 1))
plt.show()

# %%
# Creare il grafico
fig, ax = plt.subplots(figsize=(10, 5), facecolor='white')
# Impostare lo sfondo interno del grafico come bianco
ax.set_facecolor('white')

# Personalizzare il grafico
ax.plot(df4['input_size'], df4['execution_time'], marker='o', linestyle='-', color='indigo', markersize=8, linewidth=2, label='Spark SQL in locale')
ax.plot(df41['input_size'], df41['execution_time'], marker='o', linestyle='-', color='mediumpurple', markersize=8, linewidth=2, label='Spark SQL su cluster')

# Aggiungere il bordo nero
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(1.5)

# Etichette degli assi
ax.set_xlabel("Dimensione dell'input (GB)", fontsize=12, labelpad=15)
ax.set_ylabel("Tempo di esecuzione (min)", fontsize=12, labelpad=15)

# Aggiungere una griglia sottile
ax.grid(True, linestyle='--', linewidth=0.5, color='lightgray')
# Aggiungere la legenda
ax.legend()

# Aggiungere i numeri da 1 a 11 sull'asse y
ax.set_yticks(np.arange(0.5, 2.5, 0.5))
plt.show()
