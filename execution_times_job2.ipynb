# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
job_data = [
    {"input_size": 2.81, "execution_time": 4},
    {"input_size": 3.40, "execution_time": 4},
    {"input_size": 3.99, "execution_time": 7.18},
    {"input_size": 4.58, "execution_time": 8.48},
]

# Creare un DataFrame
df = pd.DataFrame(job_data)

# Creare il grafico
plt.figure(figsize=(10, 5))
plt.plot(df['input_size'], df['execution_time'], marker='o', linestyle='-', color='mediumaquamarine')
plt.xlabel('Dimensione dell\'input (GB)')
plt.ylabel('Tempo di esecuzione (min)')
plt.title('Tempo di esecuzione MapReduce (in locale) job2 in funzione della dimensione dell\'input')
plt.grid(True)
plt.show()

# %%
job_data = [
    {"input_size": 2.81, "execution_time": 11},
    {"input_size": 3.40, "execution_time": 17.25},
    {"input_size": 3.99, "execution_time": 21},
    {"input_size": 4.58, "execution_time": 24.4},
]

# Creare un DataFrame
df = pd.DataFrame(job_data)

# Creare il grafico
plt.figure(figsize=(10, 5))
plt.plot(df['input_size'], df['execution_time'], marker='o', linestyle='-', color='lightskyblue')
plt.xlabel('Dimensione dell\'input (GB)')
plt.ylabel('Tempo di esecuzione (min)')
plt.title('Tempo di esecuzione Hive (in locale) job2 in funzione della dimensione dell\'input')
plt.grid(True)
plt.show()

# %%
job_data = [
    {"input_size": 2.81, "execution_time": 3},
    {"input_size": 3.40, "execution_time": 3.48},
    {"input_size": 3.99, "execution_time": 5.30},
    {"input_size": 4.58, "execution_time": 6.40},
]

# Creare un DataFrame
df = pd.DataFrame(job_data)

# Creare il grafico
plt.figure(figsize=(10, 5))
plt.plot(df['input_size'], df['execution_time'], marker='o', linestyle='-', color='orchid')
plt.xlabel('Dimensione dell\'input (GB)')
plt.ylabel('Tempo di esecuzione (min)')
plt.title('Tempo di esecuzione Spark core (in locale) job2 in funzione della dimensione dell\'input')
plt.grid(True)
plt.show()
