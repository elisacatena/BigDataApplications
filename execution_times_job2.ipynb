# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
job_data = [
    {"input_size": 2.81, "execution_time": 3.21},
    {"input_size": 3.40, "execution_time": 4},
    {"input_size": 3.99, "execution_time": 7.18},
    {"input_size": 4.58, "execution_time": 8.48},
]

# Creare un DataFrame
df = pd.DataFrame(job_data)

# Creare il grafico
fig, ax = plt.subplots(figsize=(10, 5), facecolor='white')
# Impostare lo sfondo interno del grafico come bianco
ax.set_facecolor('white')

# Personalizzare il grafico
ax.plot(df['input_size'], df['execution_time'], marker='o', linestyle='-', color='mediumaquamarine', markersize=8, linewidth=2)

# Aggiungere il bordo nero
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(1.5)

# Etichette degli assi
ax.set_xlabel("Dimensione dell'input (GB)", fontsize=12, labelpad=15)
ax.set_ylabel("Tempo di esecuzione (min)", fontsize=12, labelpad=15)

# Titolo del grafico
ax.set_title("Tempo di esecuzione MapReduce (in locale) job2 in funzione della dimensione dell'input", fontsize=14, pad=20)

# Aggiungere una griglia sottile
ax.grid(True, linestyle='--', linewidth=0.5, color='lightgray')

plt.show()

# %%
job_data = [
    {"input_size": 2.81, "execution_time": 11},
    {"input_size": 3.40, "execution_time": 17.25},
    {"input_size": 3.99, "execution_time": 21},
    {"input_size": 4.58, "execution_time": 24.4},
]

# Creare un DataFrame
df = pd.DataFrame(job_data)

# Creare il grafico
fig, ax = plt.subplots(figsize=(10, 5), facecolor='white')
# Impostare lo sfondo interno del grafico come bianco
ax.set_facecolor('white')

# Personalizzare il grafico
ax.plot(df['input_size'], df['execution_time'], marker='o', linestyle='-', color='lightskyblue', markersize=8, linewidth=2)

# Aggiungere il bordo nero
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(1.5)

# Etichette degli assi
ax.set_xlabel("Dimensione dell'input (GB)", fontsize=12, labelpad=15)
ax.set_ylabel("Tempo di esecuzione (min)", fontsize=12, labelpad=15)

# Titolo del grafico
ax.set_title("Tempo di esecuzione MapReduce (in locale) job2 in funzione della dimensione dell'input", fontsize=14, pad=20)

# Aggiungere una griglia sottile
ax.grid(True, linestyle='--', linewidth=0.5, color='lightgray')

plt.show()

# %%
job_data = [
    {"input_size": 2.81, "execution_time": 3.33},
    {"input_size": 3.40, "execution_time": 3.48},
    {"input_size": 3.99, "execution_time": 5.30},
    {"input_size": 4.58, "execution_time": 6.04},
]

# Creare un DataFrame
df = pd.DataFrame(job_data)

# Creare il grafico
fig, ax = plt.subplots(figsize=(10, 5), facecolor='white')
# Impostare lo sfondo interno del grafico come bianco
ax.set_facecolor('white')

# Personalizzare il grafico
ax.plot(df['input_size'], df['execution_time'], marker='o', linestyle='-', color='orchid', markersize=8, linewidth=2)

# Aggiungere il bordo nero
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(1.5)

# Etichette degli assi
ax.set_xlabel("Dimensione dell'input (GB)", fontsize=12, labelpad=15)
ax.set_ylabel("Tempo di esecuzione (min)", fontsize=12, labelpad=15)

# Titolo del grafico
ax.set_title("Tempo di esecuzione MapReduce (in locale) job2 in funzione della dimensione dell'input", fontsize=14, pad=20)

# Aggiungere una griglia sottile
ax.grid(True, linestyle='--', linewidth=0.5, color='lightgray')

plt.show()

# %%
job_data = [
    {"input_size": 2.81, "execution_time": 2.48},
    {"input_size": 3.40, "execution_time": 3.27},
    {"input_size": 3.99, "execution_time": 3.45},
    {"input_size": 4.58, "execution_time": 4.25},
]

# Creare un DataFrame
df = pd.DataFrame(job_data)

# Creare il grafico
fig, ax = plt.subplots(figsize=(10, 5), facecolor='white')
# Impostare lo sfondo interno del grafico come bianco
ax.set_facecolor('white')

# Personalizzare il grafico
ax.plot(df['input_size'], df['execution_time'], marker='o', linestyle='-', color='slateblue', markersize=8, linewidth=2)

# Aggiungere il bordo nero
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(1.5)

# Etichette degli assi
ax.set_xlabel("Dimensione dell'input (GB)", fontsize=12, labelpad=15)
ax.set_ylabel("Tempo di esecuzione (min)", fontsize=12, labelpad=15)

# Titolo del grafico
ax.set_title("Tempo di esecuzione MapReduce (in locale) job2 in funzione della dimensione dell'input", fontsize=14, pad=20)

# Aggiungere una griglia sottile
ax.grid(True, linestyle='--', linewidth=0.5, color='lightgray')

plt.show()
